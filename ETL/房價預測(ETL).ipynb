# %%
import pandas as pd

pd.read_csv('all_new2-1.csv', header='infer',encoding='utf-8')

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

data_path = 'all_new2-1.csv'
df_train = pd.read_csv(data_path)

display(df_train)
# Out:
#        鄉鎮市區       交易標的            土地區段位置建物區段門牌  土地移轉總面積平方公尺 都市土地使用分區    交易年月日  \
# 0       大安區  房地(土地+建物)  台北市大安區和平東路三段1巷72弄1~30號        19.39        住  1010629
# 1       中正區  房地(土地+建物)    台北市中正區忠孝東路二段121~150號         8.46        商  1010718
# 2       大同區         土地         橋北段二小段601~630地號         5.50       其他  1010727
# 3       大同區  房地(土地+建物)      台北市大同區重慶北路一段61~90號         3.88        商  1010710
# 4       內湖區  房地(土地+建物)  台北市內湖區民權東路六段90巷6弄1~30號        32.41        住  1010710
# ...     ...        ...                     ...          ...      ...      ...
# 197941  文山區  房地(土地+建物)             興隆路三段61~90號        15.78       其他  1090712
# 197942  文山區  房地(土地+建物)            仙岩路16巷31~60號        10.57       其他  1090815
# 197943  文山區  房地(土地+建物)          興隆路三段255巷1~30號        13.78       其他  1090622
# 197944  文山區  房地(土地+建物)       興隆路三段207巷18弄1~30號        24.12       其他  1090626
# 197945  中正區  房地(土地+建物)              牯嶺街91~120號        28.03       其他  1090705
#
# ...

# %%
df_train.corr()
# Out:
#              土地移轉總面積平方公尺     交易年月日  建物移轉總面積平方公尺       總價元   單價元平方公尺  \
# 土地移轉總面積平方公尺     1.000000 -0.003725     0.145073  0.253084 -0.022368
# 交易年月日          -0.003725  1.000000    -0.009411 -0.004968  0.005223
# 建物移轉總面積平方公尺     0.145073 -0.009411     1.000000  0.655290  0.011933
# 總價元             0.253084 -0.004968     0.655290  1.000000  0.107589
# 單價元平方公尺        -0.022368  0.005223     0.011933  0.107589  1.000000
# 車位移轉總面積平方公尺     0.000479 -0.000849     0.006762  0.003703  0.025716
# 車位總價元          -0.000655 -0.013980     0.159313  0.117489  0.089161
#
#              車位移轉總面積平方公尺     車位總價元
# 土地移轉總面積平方公尺     0.000479 -0.000655
# 交易年月日          -0.000849 -0.013980
# 建物移轉總面積平方公尺     0.006762  0.159313
# 總價元             0.003703  0.117489
# 單價元平方公尺         0.025716  0.089161
# 車位移轉總面積平方公尺     1.000000  0.007818
# 車位總價元           0.007818  1.000000

# %%
#尋找缺失值
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197946 entries, 0 to 197945
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   鄉鎮市區          197946 non-null  object
#  1   交易標的          197946 non-null  object
#  2   土地區段位置建物區段門牌  197946 non-null  object
#  3   土地移轉總面積平方公尺   197946 non-null  float64
#  4   都市土地使用分區      196134 non-null  object
#  5   交易年月日         197946 non-null  int64
#  6   交易筆棟數         197946 non-null  object
#  7   移轉層次          175945 non-null  object
#  8   總樓層數          175745 non-null  object
#  9   建物型態          197946 non-null  object
#  10  主要用途          170735 non-null  object
#  11  主要建材          176144 non-null  object
#  12  建築完成年月        157265 non-null  object
#  13  建物移轉總面積平方公尺   197946 non-null  float64
#  14  有無管理組織        197946 non-null  object
#  15  總價元           197946 non-null  int64
#  16  單價元平方公尺       187264 non-null  float64
# ...

# %%
for i in df_train.columns:
    p = df_train[i].dtype 
    d = df_train[i].isnull().any()
    print(i,p,d)
# Out:
# 鄉鎮市區 object False
# 交易標的 object False
# 土地區段位置建物區段門牌 object False
# 土地移轉總面積平方公尺 float64 False
# 都市土地使用分區 object True
# 交易年月日 int64 False
# 交易筆棟數 object False
# 移轉層次 object True
# 總樓層數 object True
# 建物型態 object False
# 主要用途 object True
# 主要建材 object True
# 建築完成年月 object True
# 建物移轉總面積平方公尺 float64 False
# 有無管理組織 object False
# 總價元 int64 False
# 單價元平方公尺 float64 True
# 車位類別 object True
# 車位移轉總面積平方公尺 float64 False
# 車位總價元 int64 False

# %%
i = '交易年月日'
p = df_train[i].dtype
d = df_train[i].isnull().any()
print(i,p,d)
# Out:
# 交易年月日 int64 False

# %%
i = '交易筆棟數'
p = df_train[i].dtype
d = df_train[i].isnull().any()
print(i,p,d)
# Out:
# 交易筆棟數 object False

# %%
i = '移轉層次'
p = df_train[i].dtype
d = df_train[i].isnull().any()
print(i,p,d)
# Out:
# 移轉層次 object True

# %%
i = '總樓層數'
p = df_train[i].dtype
d = df_train[i].isnull().any()
print(i,p,d)
# Out:
# 總樓層數 object True

# %%
#處理'交易年月日'=>'年','月'
import pandas as pd
import numpy as np

df_train_1 = pd.DataFrame()
df_train_1['建築完成年'] = df_train['交易年月日'].apply(str).apply(lambda x: x[:-4])
df_train_1['建築完成年'].isnull().any()
df_train_1['建築完成年'][df_train_1['建築完成年']==''] = '0'
df_train_1['建築完成年'] = df_train_1['建築完成年'].apply(int)
df_train_1['建築完成年']
# Out:
# 0         101
# 1         101
# 2         101
# 3         101
# 4         101
#          ...
# 197941    109
# 197942    109
# 197943    109
# 197944    109
# 197945    109
# Name: 建築完成年, Length: 197946, dtype: int64

# %%
df_train_1['建築完成月'] = df_train['交易年月日'].apply(str).apply(lambda x: x[-4:-2]).apply(float)
df_train_1['建築完成月']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-499dbfc428a4> in <module>
# ----> 1 df_train_1['建築完成月'] = df_train['交易年月日'].apply(str).apply(lambda x: x[-4:-2]).apply(float)
#       2 df_train_1['建築完成月']
#
# ~\anaconda3\envs\Python_course\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3847             else:
#    3848                 values = self.astype(object).values
# -> 3849                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3850
#    3851         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: could not convert string to float: ''

# %%
#處理'交易筆棟數'=>'交易筆棟數_土地','交易筆棟數_建物','交易筆棟數_車位'
import pandas as pd
import numpy as np
import re

df_train_1['交易筆棟數_土地'] = df_train['交易筆棟數'].apply(lambda x:int(re.findall(r'\d+',x)[0])) 
df_train_1['交易筆棟數_建物'] = df_train['交易筆棟數'].apply(lambda x:int(re.findall(r'\d+',x)[1]))
df_train_1['交易筆棟數_車位'] = df_train['交易筆棟數'].apply(lambda x:int(re.findall(r'\d+',x)[2]))

display(df_train_1)
# Out:
#         建築完成年  交易筆棟數_土地  交易筆棟數_建物  交易筆棟數_車位
# 0         101         1         2         0
# 1         101         3         1         0
# 2         101         1         0         0
# 3         101         4         1         0
# 4         101         1         1         0
# ...       ...       ...       ...       ...
# 197941    109         2         1         0
# 197942    109         1         1         0
# 197943    109         3         1         0
# 197944    109         1         1         0
# 197945    109         2         1         0
#
# [197946 rows x 4 columns]

# %%
display(df_train['總樓層數'].unique())
# Out:
# array(['十七層', '十二層', nan, '十一層', '五層', '七層', '四層', '十五層', '六層', '十四層',
#        '十三層', '二層', '十層', '二十五層', '九層', '八層', '十九層', '十八層', '三層', '二十一層',
#        '二十層', '二十二層', '十六層', '一層', '二十四層', '二十三層', '二十六層', '二十九層', '二十七層',
#        '三十層', '二十八層', '三十二層', '三十五層', '三十一層', '四十二層', '三十八層', '三十三層'],
#       dtype=object)

# %%
import pandas as pd
import numpy as np
#空值先取 0
i = {np.nan:0, '十七層':17, '十二層':12, '十一層':11, '五層':5, '七層':7, '四層':4, '十五層':15, '六層':6, '十四層':14,
       '十三層':13, '二層':2, '十層':10, '二十五層':25, '九層':9, '八層':8, '十九層':19, '十八層':18, '三層':3, '二十一層':21,
       '二十層':20, '二十二層':22, '十六層':16, '一層':1, '二十四層':24, '二十三層':23, '二十六層':26, '二十九層':29, '二十七層':27,
       '三十層':30, '二十八層':28, '三十二層':32, '三十五層':35, '三十一層':31, '四十二層':42, '三十八層':38, '三十三層':33}

df_train_1['總樓層數'] = df_train['總樓層數'].apply(lambda x: i[x]).apply(int)

df_train_1['總樓層數']
# Out:
# 0         17
# 1         12
# 2          0
# 3         11
# 4          5
#           ..
# 197941    11
# 197942     8
# 197943     5
# 197944     5
# 197945     7
# Name: 總樓層數, Length: 197946, dtype: int64

# %%
display(df_train['移轉層次'].unique())
# Out:
# array(['五層', '九層', nan, '六層', '三層', '七層', '一層', '二層', '四層', '一層，平台', '十層',
#        '全', '十一層', '十二層', '八層', '十層，十一層，屋頂突出物', '十三層', '七層，電梯樓梯間', '地下二層',
#        '四層，陽台', '一層，騎樓', '十四層', '十五層', '十六層', '一層，停車場', '八層，陽台', '三層，陽台',
#        '十八層', '五層，陽台', '九層，陽台，電梯樓梯間', '地下一層，地下二層，地下三層，地下四層', '一層，夾層',
#        '地下四層', '一層，地下一層', '二層，陽台', '七層，陽台', '七層，見其他登記事項', '一層，二層',
#        '十層，十一層', '一層，騎樓，地下一層', '六層，電梯樓梯間', '四層，五層', '一層，騎樓，停車場', '十七層',
#        '二層，三層', '十九層', '四層，電梯樓梯間', '九層，十層', '十層，電梯樓梯間', '平台，一層', '地下三層',
#        '三層，露台', '十二層，十三層', '地下層', '五層，夾層', '一層，儲藏室', '地下一層，見使用執照',
#        '二層，露台', '地下一層', '三層，電梯樓梯間', '十八層，十九層', '五層，六層', '一層，騎樓，露台',
#        '十一層，陽台', '一層，二層，騎樓', '九層，陽台', '二十層', '二十四層', '六層，陽台', '陽台，二層',
#        '一層，電梯樓梯間', '地下一層，地下二層，地下三層', '三層，四層', '二十一層', '一層，騎樓，夾層',
#        '五層，電梯樓梯間', '八層，九層', '十三層，十四層', '二層，電梯樓梯間', '十四層，見其他登記事項',
#        '八層，電梯樓梯間', '十層，九層', '陽台，六層', '一層，二層，三層，四層', '一層，通道',
# ...

# %%
import pandas as pd
import numpy as np

i = {np.nan:0, '地下一層，見使用執照','地下層', '地下三層','地下四層', '地下一層，地下二層，地下三層，地下四層','地下二層':,'全':,'五層':5, '九層':9, '六層':6, '三層':3, '七層':7, '一層':1, '二層':2, '四層':4, '一層，平台':1, '十層':10,
        '十一層':11, '十二層':12, '八層':8, '十層，十一層，屋頂突出物':11, '十三層':13, '七層，電梯樓梯間':7,
       '四層，陽台':4, '一層，騎樓':1, '十四層':14, '十五層':15, '十六層':16, '一層，停車場':1, '八層，陽台':8, '三層，陽台':3,
       '十八層':18, '五層，陽台':5, '九層，陽台，電梯樓梯間':9, '一層，夾層':1,
       '一層，地下一層':1, '二層，陽台':2, '七層，陽台':7, '七層，見其他登記事項':7, '一層，二層':1,
       '十層，十一層':11, '一層，騎樓，地下一層':1, '六層，電梯樓梯間':6, '四層，五層':5, '一層，騎樓，停車場':1, '十七層':17,
       '二層，三層':3, '十九層':19, '四層，電梯樓梯間':4, '九層，十層':10, '十層，電梯樓梯間':10, '平台，一層':1,
       '三層，露台':3, '十二層，十三層':13,  '五層，夾層':5, '一層，儲藏室':1,
       '二層，露台', '地下一層', '三層，電梯樓梯間', '十八層，十九層', '五層，六層', '一層，騎樓，露台',
       '十一層，陽台', '一層，二層，騎樓', '九層，陽台', '二十層', '二十四層', '六層，陽台', '陽台，二層',
       '一層，電梯樓梯間', '地下一層，地下二層，地下三層', '三層，四層', '二十一層', '一層，騎樓，夾層',
       '五層，電梯樓梯間', '八層，九層', '十三層，十四層', '二層，電梯樓梯間', '十四層，見其他登記事項',
       '八層，電梯樓梯間', '十層，九層', '陽台，六層', '一層，二層，三層，四層', '一層，通道',
       '四層，五層，屋頂突出物，夾層', '六層，走廊', '七層，八層', '電梯樓梯間，十層', '地下二層，地下三層，地下四層',
       '二層，倉庫', '一層，二層，三層', '夾層，一層', '地下三層，地下四層', '九層，見使用執照', '六層，見使用執照',
       '二十二層', '二十三層', '二層，通道', '十四層，十五層', '地下二層，地下三層', '十二層，夾層', '二層，一層',
       '十七層，屋頂突出物，夾層', '地下一層，地下二層', '陽台，三層', '二層，走廊', '三層，二層', '十九層，二十層',
       '地下一層，地下三層', '地下五層', '四層，走廊', '二層，見使用執照', '停車場，地下層', '二十五層',
       '六層，五層', '陽台，四層', '十三層，夾層', '七層，見使用執照', '五層，屋頂突出物', '夾層',
       '地下二層，地下三層，地下五層，地下四層', '電梯樓梯間，二層', '一層，二層，騎樓，夾層', '十五層，夾層',
       '見使用執照', '六層，七層', '八層，九層，十層', '騎樓，一層', '二十六層', '二十七層',
       '四層，屋頂突出物，一層，二層，三層', '十三層，電梯樓梯間', '一層，地下層', '四層，五層，六層', '六層，七層，夾層',
       '九層，見其他登記事項', '十層，見其他登記事項', '十七層，十八層', '六層，露台，走廊',
       '一層，二層，陽台，平台，騎樓', '一層，二層，三層，地下一層，見其他登記事項', '陽台，五層', '五層，見其他登記事項',
       '一層，平台，騎樓', '一層，三層，四層，平台，陽台，二層', '騎樓，地下一層，一層', '五層，見使用執照', '四層，露台',
       '地下三層，地下二層', '一層，地下一層，見其他登記事項，三層，二層', '通道，一層', '二十九層', '一層，二層，夾層',
       '一層，地下一層，地下二層，地下三層', '十一層，電梯樓梯間', '一層，二層，三層，騎樓', '陽台，地下一層',
       '十層，陽台', '二層，三層，四層，電梯樓梯間', '六層，見其他登記事項', '地下二層，地下三層，地下一層',
       '十二層，電梯樓梯間', '十七層，夾層', '防空避難室，見使用執照', '十一層，十二層', '九層，電梯樓梯間',
       '一層，露台', '十三層，十四層，屋頂突出物', '一層，二層，三層，四層，騎樓，地下層',
       '三層，四層，五層，六層，一層，騎樓，七層，二層', '五層，四層', '平台，騎樓，一層',
       '一層，二層，地下一層，三層，見其他登記事項', '騎樓，二層，一層', '電梯樓梯間，八層', '八層，見使用執照',
       '四層，騎樓，二層，一層，三層', '十四層，夾層', '十二層，陽台', '十層，夾層', '十二層，十四層，十三層',
       '二層，門廳', '陽台，七層', '露台，二層', '通道，地下二層', '十六層，電梯樓梯間',
       '地下三層，地下四層，地下五層', '十三層，十二層', '十五層，見其他登記事項', '地下三層，地下二層，地下四層',
       '四層，通道', '一層，見其他登記事項', '電梯樓梯間，地下一層', '一層，陽台，騎樓', '見其他登記事項，五層',
       '二層，三層，四層，五層，六層，七層', '一層，地下四層', '五層，屋頂突出物，四層，夾層', '二層，地下一層',
       '四層，見使用執照', '七層，夾層', '二層，陽台，見其他登記事項', '一層，地下三層', '三層，走廊',
       '平台，地下層，一層', '一層，停車場，通道', '十五層，十六層', '騎樓，一層，二層',
       '地下二層，地下三層，地下四層，地下五層', '平台，一層，二層，陽台', '一層，二層，陽台，平台', '一層，見使用執照',
       '三層，四層，屋頂突出物，見其他登記事項', '十三層，見其他登記事項', '一層，平台，騎樓，停車場', '停車場，見使用執照',
       '十四層，十三層', '一層，二層，屋頂突出物，騎樓', '十四層，電梯樓梯間', '二層，陽台，電梯樓梯間', '三層，騎樓',
       '十一層，夾層', '三層，見使用執照', '六層，夾層', '一層，騎樓，地下層', '十二層，十一層', '九層，夾層',
       '五層，陽台，見其他登記事項', '陽台，電梯樓梯間，六層', '停車場，地下三層',
       '一層，二層，三層，四層，屋頂突出物，地下一層', '一層，露台，走廊', '一層，二層，三層，四層，五層，騎樓', '八層，夾層',
       '一層，二層，地下層', '二十八層，電梯樓梯間', '十八層，十九層，電梯樓梯間', '地下三層，一層，地下一層，地下二層',
       '二層，見其他登記事項', '四層，夾層', '門廳，三層', '防空避難室', '一層，二層，騎樓，露台', '電梯樓梯間，三層',
       '防空避難室，電梯樓梯間', '四層，三層', '二層，三層，四層', '電梯樓梯間，四層', '騎樓，一層，平台',
       '二層，騎樓', '十五層，電梯樓梯間', '地下一層，地下三層，地下二層', '十一層，見其他登記事項', '走廊，地下一層',
       '地下層，見使用執照', '騎樓，停車場，一層', '二層，地下層', '十層，平台', '十八層，電梯樓梯間',
       '一層，二層，三層，四層，地下層', '電梯樓梯間，六層', '一層，騎樓，電梯樓梯間，地下一層', '四層，五層，見其他登記事項',
       '二十層，電梯樓梯間', '十六層，十七層', '一層，二層，三層，四層，騎樓', '六層，通道', '五層，露台',
       '三層，四層，二層，一層', '九層，十層，陽台', '二層，陽台，走廊', '十一層，露台', '地下六層', '露台，三層',
       '十七層，電梯樓梯間', '防空避難室，地下層，見使用執照', '停車場，一層', '一層，陽台', '五層，走廊',
       '一層，平台，騎樓，地下一層', '走廊，一層', '二十層，二十一層', '騎樓，電梯樓梯間，地下一層，地下二層',
       '五層，機械房', '一層，平台，騎樓，地下層', '六層，陽台，見使用執照', '地下二層，地下一層',
       '六層，七層，電梯樓梯間',
       '地下二層，地下三層，地下四層，一層，二層，三層，四層，五層，六層，七層，八層，九層，十層，十一層，十二層，屋頂突出物，地下一層',
       '地下三層，地下四層，地下一層，地下二層', '地下四層，地下一層，地下三層，地下二層', '四層，見其他登記事項',
       '夾層，三層，四層', '一層，二層，騎樓，停車場', '地下三層，地下四層，地下二層，地下五層', '八層，七層',
       '地下三層，地下四層，地下五層，地下二層', '七層，夾層，六層', '地下層，一層，平台', '一層，走廊',
       '防空避難室，地下層', '地下層，一層，二層，三層，四層，五層，六層，七層，騎樓', '停車場，一層，平台',
       '一層，平台，地下層', '七層，露台', '四層，五層，電梯樓梯間', '屋頂突出物', '一層，二層，三層，屋頂突出物',
       '地下二層，地下三層，地下一層，地下四層', '二層，三層，騎樓，露台，一層', '一層，騎樓，見使用執照', '電梯樓梯間，五層',
       '一層，騎樓，地下一層，地下二層', '地下一層，地下二層，地下四層，地下三層', '電梯樓梯間，機械房，地下三層',
       '三層，通道', '電梯樓梯間，十一層', '二層，三層，四層，五層', '五層，六層，電梯樓梯間', '一層，露台，地下層',
       '四層，五層，陽台', '十四層，十五層，電梯樓梯間', '一層，夾層，地下一層', '夾層，七層', '五層，通道',
       '二十一層，二十層', '一層，停車場，走廊', '機械房，地下四層，電梯樓梯間', '二十三層，二十四層',
       '十七層，十八層，電梯樓梯間', '二十一層，二十二層', '十層，電梯樓梯間，十一層', '一層，三層，四層，夾層',
       '走廊，二層，露台', '一層，屋頂突出物', '六層，七層，陽台', '一層，二層，三層，四層，地下一層', '四層，平台',
       '地下四層，地下五層，地下三層，地下二層', '一層，二層，三層，四層，五層，六層，七層，停車場', '露台，七層',
       '一層，二層，三層，地下一層', '十五層，十四層', '五層，屋頂突出物，夾層，四層', '三層，四層，一層，屋頂突出物，二層',
       '二層，平台', '三層，四層，五層', '一層，二層，三層，四層，地下一層，地下二層', '十二層，見其他登記事項',
       '夾層，見使用執照，一層', '二層，夾層', '地下層，一層', '三層，四層，一層，二層', '一層，夾層，走廊',
       '一層，二層，陽台，騎樓，露台', '七層，陽台，電梯樓梯間', '地下四層，地下二層，地下三層',
       '地下三層，地下一層，地下二層', '六層，露台', '七層，走廊', '七層，機械房', '十五層，十六層，十七層',
       '九層，八層', '露台，一層', '三層，一層，二層', '一層，二層，三層，四層，五層，六層，七層，八層，九層，十層，騎樓',
       '十一層，陽台，電梯樓梯間', '一層，走廊，地下層', '十層，通道', '見其他登記事項，四層', '一層，地下一層，地下二層',
       '二十二層，二十三層', '二層，騎樓，一層', '二層，一層，三層', '停車場', '一層，騎樓，停車場，通道，門廳',
       '四層，五層，三層', '地下一層，一層', '四層，騎樓', '二十四層，二十五層', '二十八層，二十九層',
       '二十六層，二十七層', '一層，平台，停車場', '一層，二層，三層，五層，四層', '十二層，十三層，十四層',
       '二十五層，電梯樓梯間', '一層，騎樓，走廊', '十一層，門廳', '一層，二層，三層，屋頂突出物，騎樓',
       '二層，夾層，一層', '八層，見其他登記事項', '五層，電梯樓梯間，夾層', '三層，四層，夾層', '一層，停車場，門廳',
       '夾層，五層', '九層，露台', '一層，三層，五層，四層，二層', '見其他登記事項，一層，騎樓',
       '一層，二層，屋頂突出物，地下一層，地下二層', '露台，一層，騎樓', '停車場，地下一層，地下二層',
       '停車場，見其他登記事項', '二層，三層，一層，騎樓，露台', '三層，地下一層，一層，二層', '屋頂突出物，夾層，四層，五層',
       '一層，二層，電梯樓梯間', '見其他登記事項', '二十八層，夾層', '見其他登記事項，十三層', '地下層，見其他登記事項',
       '一層，屋頂突出物，夾層', '十三層，陽台', '七層，騎樓，地下一層，一層，二層，三層，四層，五層，六層',
       '四層，五層，夾層', '十九層，夾層', '地下一層，地下二層，一層', '三層，騎樓，露台', '十層，見使用執照',
       '七層，屋頂突出物，夾層', '六層，陽台，見其他登記事項', '三層，露台，走廊', '十六層，十七層，電梯樓梯間',
       '停車場，地下二層', '地下一層，地下二層，地下三層，一層', '十二層，屋頂突出物', '電梯樓梯間，十九層',
       '停車場，地下一層', '十九層，十八層', '八層，走廊', '見其他登記事項，六層', '五層，夾層，門廳',
       '地下四層，地下三層', '五層，電梯樓梯間，四層', '見其他登記事項，二層，三層', '一層，騎樓，見其他登記事項',
       '陽台，見其他登記事項', '電梯樓梯間，十四層，十五層', '六層，七層，屋頂突出物',
       '八層，九層，一層，二層，三層，四層，五層，六層，七層，十層，十一層，陽台，騎樓，地下層', '夾層，十三層',
       '騎樓，一層，二層，三層，四層，陽台，平台', '一層，二層，三層，四層，陽台，平台，騎樓', '十二層，走廊',
       '一層，露台，地下一層', '四層，機械房', '屋頂突出物，地下一層，一層，二層，三層，四層，五層，六層，七層，八層，九層，十層',
       '十一層，屋頂突出物，見其他登記事項', '露台，四層', '十四層，見使用執照',
       '一層，二層，三層，四層，五層，六層，七層，八層，騎樓', '騎樓，一層，二層，三層，四層，五層，六層，七層，八層',
       '四層，陽台，電梯樓梯間', '三層，陽台，電梯樓梯間', '屋頂突出物，二層，一層，見其他登記事項', '十二層，門廳',
       '十層，露台', '地下一層，見其他登記事項', '三十層', '三十九層', '騎樓，見使用執照，一層',
       '三層，四層，見其他登記事項，屋頂突出物', '一層，二層，平台，騎樓，陽台', '十層，電梯樓梯間，夾層', '騎樓，夾層，一層',
       '三十八層', '二十八層', '露台，一層，走廊', '三層，電梯樓梯間，陽台', '二層，一層，騎樓',
       '地下一層，地下四層，地下三層，地下二層', '一層，二層，停車場', '一層，露台，騎樓，二層', '七層，通道',
       '走廊，二層', '一層，二層，三層，四層，五層，六層，七層', '陽台，十層', '電梯樓梯間，八層，陽台', '十五層，陽台',
       '一層，二層，三層，屋頂突出物，地下一層', '騎樓，一層，夾層', '地下二層，地下四層，地下三層', '八層，陽台，電梯樓梯間',
       '見其他登記事項，十一層', '十層，走廊', '四層，陽台，走廊', '屋頂突出物，一層', '三十二層',
       '一層，二層，屋頂突出物', '防空避難室，停車場', '一層，平台，走廊', '避難室兼停車場，見使用執照',
       '見使用執照，停車場', '五層，陽台，電梯樓梯間', '三十七層，三十八層', '四層，五層，一層，二層，三層，騎樓',
       '見使用執照，四層', '三十一層', '十五層，電梯樓梯間，十四層',
       '一層，二層，三層，四層，五層，六層，七層，八層，屋頂突出物，騎樓，地下一層，地下二層，地下三層，地下四層，地下五層',
       '十四層，屋頂突出物，夾層', '一層，騎樓，停車場，地下層', '防空避難室，倉庫，見使用執照', '一層，二層，見其他登記事項',
       '五層，電梯樓梯間，通道', '三十三層', '十二層，十三層，電梯樓梯間', '一層，騎樓，通道，電梯樓梯間',
       '電梯樓梯間，十層，十一層', '一層，門廳', '防空避難室，騎樓，電梯樓梯間', '地下三層，地下四層，地下二層',
       '六層，機械房', '一層，騎樓，通道', '一層，二層，三層，四層，五層，六層，七層，八層，九層，十層，騎樓，地下層',
       '騎樓，一層，二層，三層，四層，五層，陽台', '陽台，屋頂突出物，四層', '十九層，二十層，電梯樓梯間',
       '二十四層，電梯樓梯間', '防空避難室，停車場，見使用執照', '地下四層，地下二層，地下三層，地下一層',
       '十九層，電梯樓梯間', '走廊，地下層', '三層，四層，走廊', '四層，五層，二層，三層', '四層，五層，屋頂突出物',
       '一層，地下層，見使用執照', '三層，騎樓，一層，二層', '二十六層，電梯樓梯間，二十五層', '防空避難室，見其他登記事項',
       '走廊，五層', '四層，露台，走廊', '十七層，見其他登記事項', '十九層，屋頂突出物', '八層，陽台，見使用執照',
       '倉庫，地下層', '三層，四層，屋頂突出物', '陽台，電梯樓梯間，三層', '電梯樓梯間，夾層，四層', '陽台，一層',
       '二十一層，見其他登記事項', '十四層，屋頂突出物', '一層，二層，地下一層', '二十五層，見其他登記事項',
       '電梯樓梯間，九層', '見其他登記事項，二十五層', '二層，三層，見其他登記事項', '電梯樓梯間，七層', '八層，露台',
       '三十五層', '陽台，屋頂突出物', '四層，陽台，屋頂突出物', '十二層，露台', '三層，四層，電梯樓梯間',
       '三層，屋頂突出物，一層，二層', '十層，陽台，電梯樓梯間', '三層，四層，陽台', '三層，四層，騎樓，一層，二層',
       '屋頂突出物，四層', '電梯樓梯間，地下層', '六層，電梯樓梯間，七層', '騎樓，露台，一層', '夾層，十九層',
       '地下四層，一層', '一層，停車場，騎樓', '一層，二層，三層，屋頂突出物，見其他登記事項，地下二層，地下一層，四層',
       '一層，二層，三層，四層，地下三層，屋頂突出物', '一層，三層，四層，五層，六層，陽台，屋頂突出物，地下層',
       '一層，二層，三層，四層，五層，六層，七層，地下一層，地下二層', '六層，騎樓', '一層，二層，三層，四層，屋頂突出物',
       '十四層，陽台', '三層，平台', '五層，六層，七層', '見使用執照，防空避難室', '二層，陽臺', '三層，陽臺',
       '四層，陽臺', '三層，四層，見其他登記事項', '地下三層，地下四層，地下二層，地下一層', '五層，六層，陽台',
       '夾層，一層，騎樓', '一層，平台，地下一層', '六層，陽台，電梯樓梯間', '一層，騎樓，停車場，門廳，通道',
       '七層，電梯樓梯間，露台', '騎樓，一層，二層，三層，四層，五層', '八層，屋頂突出物', '一層，二層，地下一層，三層',
       '五層，平台', '一層，二層，陽台', '十四層，陽台，電梯樓梯間', '七層，屋頂突出物',
       '地下一層，地下二層，一層，地下三層', '三十四層', '電梯樓梯間，二十九層', '一層，二層，三層，四層，五層，六層，地下層',
       '一層，二層，三層，四層，五層，地下一層', '三十六層', '十層，騎樓', '騎樓，一層，二層，陽台，平台',
       '六層，七層，見其他登記事項', '十四層，十五層，十三層', '二層，機械房', '五層，三層，四層', '一層，夾層，騎樓',
       '一層，二層，三層，四層，五層，六層，七層，地下層', '地下一層，電梯樓梯間', '見其他登記事項，七層',
       '一層，騎樓，電梯樓梯間', '避難室兼停車場', '一層，陽台，平台', '地下層，一層，騎樓', '一層，二層，陽台，露台',
       '七層，露台，走廊', '三層，四層，五層，夾層', '夾層，地下層', '地下三層，一層', '見使用執照，二層',
       '三層，四層，二層', '一層，三層，四層，五層，陽台，地下層，屋頂突出物，六層', '地下層，一層，二層',
       '一層，地下一層，地下三層，地下二層', '二十四層，見其他登記事項', '見使用執照，七層', '電梯樓梯間，走廊，地下二層',
       '一層，三層，騎樓，四層，二層', '電梯樓梯間，地下二層', '四十二層',
       '一層，二層，三層，四層，五層，六層，七層，八層，九層，十層，十一層，陽台，騎樓，地下層', '一層，二層，三層，五層，夾層，四層',
       '地下四層，地下五層，地下二層，地下三層', '停車場，一層，騎樓', '地下四層，地下五層',
       '地下一層，一層，二層，四層，屋頂突出物，三層', '十一層，十層', '一層，露台，通道', '一層，騎樓，門廳',
       '六層，陽臺', '七層，陽臺', '五層，陽臺', '六層，陽臺，見使用執照', '八層，陽臺', '十二層，陽臺',
       '十二層，見使用執照', '陽臺，地下一層', '一層，二層，陽臺，平台，騎樓'}
