# %% [markdown]
# # Use Lasso to do feature selection first and then do polynomial regression

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

df = pd.read_csv('./house_data.csv')

y = df['建物單價元/坪']
X = df.drop(['建物單價元/坪'],axis=1)

print('X shape: {}'.format(X.shape))
print('y shape: {}'.format(y.shape))

diabetes_X_train, diabetes_X_test, diabetes_y_train, diabetes_y_test = train_test_split(X, y, test_size=0.1)

model = linear_model.Lasso(alpha=0.1)
# model = linear_model.Ridge(alpha=1.0)
# model = linear_model.ElasticNet(alpha=1.0, l1_ratio=0.5)

model.fit(diabetes_X_train, diabetes_y_train)

diabetes_y_pred = model.predict(diabetes_X_test)


mask = model.coef_ != 0
print(mask)
X = X.iloc[:, mask]
print('after feature extraction\nX shape: {}'.format(X.shape))
display(X)
# print(X.head())
# Out:
# X shape: (143788, 49)
# y shape: (143788,)
# [ True  True False  True  True  True  True False False  True False  True
#  False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True  True  True  True
#   True False False False False False False False False  True False  True
#  False]
# after feature extraction
# X shape: (143788, 33)
# C:\Users\DA01015\anaconda3\envs\Python_course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205850.87956362963, tolerance: 13357.003196683283
#   model = cd_fast.enet_coordinate_descent(
#            房貸負擔比   房貸案件樣本數      總人口數       出生率     移出人口數     移入人口數  M1B(年增率)  \
# 0       2.292568  0.792027  1.463351 -0.046466  2.310506  2.349618 -1.819556
# 1       2.292568 -1.082785 -1.481937  0.362481  0.355374  0.587298 -2.074228
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

df = pd.read_csv('./house_data.csv')

y = df['建物單價元/坪']
X = df.drop(['建物單價元/坪'],axis=1)

print('X shape: {}'.format(X.shape))
print('y shape: {}'.format(y.shape))

diabetes_X_train, diabetes_X_test, diabetes_y_train, diabetes_y_test = train_test_split(X, y, test_size=0.1)

model = linear_model.Lasso(alpha=0.1)
# model = linear_model.Ridge(alpha=1.0)
# model = linear_model.ElasticNet(alpha=1.0, l1_ratio=0.5)

model.fit(diabetes_X_train, diabetes_y_train)

diabetes_y_pred = model.predict(diabetes_X_test)

# The coefficients
print('Coefficients: {}\n'.format(model.coef_))
# The mean squared error
print("Mean squared error: {}".format((mean_squared_error(diabetes_y_test, diabetes_y_pred))))
# Explained variance score: 1 is perfect prediction
print('R2 score: {}'.format(r2_score(diabetes_y_test, diabetes_y_pred)))
print('number of model coef: {}'.format(np.sum(model.coef_ != 0))) #確認非0的欄位!!!!
# Out:
# X shape: (143788, 49)
# y shape: (143788,)
# Coefficients: [ 1.29753753e-01 -2.59731400e+00 -0.00000000e+00  1.95460325e-01
#  -1.94866514e+00  9.30977622e-01  1.65135052e+00  0.00000000e+00
#  -0.00000000e+00  4.32280594e-01 -0.00000000e+00 -6.41478509e-01
#   0.00000000e+00  1.30189967e+00  1.66571746e+01  3.12841635e+00
#  -7.58178277e+00  3.61684769e-01  3.02647889e+00 -3.31705348e+00
#  -5.99641072e-01 -2.33886036e+00  1.54258363e+00 -2.92100899e+01
#   2.45643690e+01 -4.10551722e-01 -3.61396022e+00  1.23559556e+00
#   2.86178727e-01  4.15256494e-01 -3.85735924e+00 -0.00000000e+00
#  -1.19305659e+00 -2.76127703e-03 -1.26425308e-04 -5.03596789e-01
#  -2.78325888e-01  0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  1.26440130e+00  0.00000000e+00 -2.24018085e-02
#   0.00000000e+00]
#
# Mean squared error: 250.6552448025395
# R2 score: 0.6865831990661395
# number of model coef: 33
# ...

# %%
mask = model.coef_ != 0
print(mask)
X = X.iloc[:, mask]
print('after feature extraction\nX shape: {}'.format(X.shape))
display(X)
# print(X.head())
# Out:
# [ True  True False  True  True  True  True False False  True False  True
#  False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True  True  True  True
#   True False False False False False False False False  True False  True
#  False]
# after feature extraction
# X shape: (143788, 33)
#            房貸負擔比   房貸案件樣本數      總人口數       出生率     移出人口數     移入人口數  M1B(年增率)  \
# 0       2.292568  0.792027  1.463351 -0.046466  2.310506  2.349618 -1.819556
# 1       2.292568 -1.082785 -1.481937  0.362481  0.355374  0.587298 -2.074228
# 2       2.292568 -1.444818 -2.155231  2.141061 -1.261833 -0.515503 -2.074228
# 3       2.292568  2.479358  0.730807  1.061710  1.217426  2.140591 -2.074228
# 4       2.292568 -0.151844 -0.543390  0.233139  0.841571  1.070224 -2.074228
# ...          ...       ...       ...       ...       ...       ...       ...
# 143783 -0.326873  0.662730  0.647717 -2.136826  1.241563  0.172847  2.527645
# ...

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2).fit(X)
X_poly = poly.transform(X)

X_train,X_test,y_train,y_test=train_test_split(X_poly, y, test_size=0.3, random_state=1) #random_state 種子值


scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)


model = linear_model.LinearRegression()
model.fit(X_train, y_train)

X_test = scaler.transform(X_test)
y_pred = model.predict(X_test)

# The coefficients
# print('Coefficients: {}\n'.format(model.coef_))
# The mean squared error
print("Mean squared error: {}".format(mean_squared_error(y_test, y_pred)))
# Explained variance score: 1 is perfect prediction
print('R2 score: {}'.format(r2_score(y_test, y_pred)))
# Out:
# Mean squared error: 753.8855170979634
# R2 score: 0.4859185260180603
